# %%
from facepy import GraphAPI

# Initialize the Graph API with a valid access token (optional,
# but will allow you to do all sorts of fun stuff).
graph = GraphAPI("EAACEQkPzZBEQBAOaAaKX6JZCsBx3yLJjnXtXR7ZCZAuggxTTAIgXVCutZBEfZBW0ntnIOwHZAtDAZB0rn2eovxlRGeaEkmF50xfxBEzERfRyIamhau2Uv7INgoULMsycZCNTxY3sENe8eDBUVslOTsZBvbWOI6xXuTAi0mTiKalYGQPEf6maP7FUe1Pt6SrdiNHZCGTCIjUbt64c3jeVDkZCxoA3")

# Get my latest posts
posts = graph.get('me/posts')

# %%
posts['paging']['next']
# Out:
# 'https://graph.facebook.com/v2.11/112757542843617/posts?access_token=EAACEQkPzZBEQBAOaAaKX6JZCsBx3yLJjnXtXR7ZCZAuggxTTAIgXVCutZBEfZBW0ntnIOwHZAtDAZB0rn2eovxlRGeaEkmF50xfxBEzERfRyIamhau2Uv7INgoULMsycZCNTxY3sENe8eDBUVslOTsZBvbWOI6xXuTAi0mTiKalYGQPEf6maP7FUe1Pt6SrdiNHZCGTCIjUbt64c3jeVDkZCxoA3&limit=25&until=1512252871&__paging_token=enc_AdCvmOVOK2CWOcoyZBwqxTAOvbSO8cUwCVzWn0YZAlZBjOOFBbbBwYqAAL9VKBa26NctBvgQ9kaJM8bd93bvVoZA71OQN7kbDJKWazLiJbzO36ZB3YAZDZD'

# %%
import requests

# %%
post_limit = 100
x = requests.get(f"https://graph.facebook.com/v2.11/112757542843617/posts?access_token=EAACEQkPzZBEQBAOaAaKX6JZCsBx3yLJjnXtXR7ZCZAuggxTTAIgXVCutZBEfZBW0ntnIOwHZAtDAZB0rn2eovxlRGeaEkmF50xfxBEzERfRyIamhau2Uv7INgoULMsycZCNTxY3sENe8eDBUVslOTsZBvbWOI6xXuTAi0mTiKalYGQPEf6maP7FUe1Pt6SrdiNHZCGTCIjUbt64c3jeVDkZCxoA3&limit={post_limit}&__paging_token=enc_AdCvmOVOK2CWOcoyZBwqxTAOvbSO8cUwCVzWn0YZAlZBjOOFBbbBwYqAAL9VKBa26NctBvgQ9kaJM8bd93bvVoZA71OQN7kbDJKWazLiJbzO36ZB3YAZDZD").json()

# %%
posts = []
months = {
    9:"September",
    10:"October",
    11:"November",
    12:"December"
}

for n in range(len(x['data'])):
    try:
        message = x['data'][n]['message']
        day = n%30 + 1
        month = n//30 + 9
        year = 2017
        date = f"{day:02d}/{month:02d}/{year}"
        posts.append([message,day,month,year,date])
    except:
        pass

# %%
import pandas as pd

df = pd.DataFrame(posts,columns=["message","day","month","year","date"])

# %%
df
# Out:
#                                               message  day  month  year  \
# 0   I always liked to run/exercise but was never v...    1      9  2017
# 1   Doesn't matter what it was about, it's the typ...    2      9  2017
# 2   I don't understand what he's talking about but...    3      9  2017
# 3   I was having dinner with my boyfriend after wo...    4      9  2017
# 4   I don't know if this is the right subreddit fo...    5      9  2017
# 5   Bothers me i take everything to heart when oth...    6      9  2017
# 6   Two weeks ago, there I was re-watching "The Gi...    7      9  2017
# 7   I really enjoying this weeks Marry Me Episode....    8      9  2017
# 8   Which is too bad because I was going to sugges...    9      9  2017
# 9   I had never heard of this show but discovered ...   10      9  2017
# 10  Was it just made for the show or?    Great son...   11      9  2017
# 11  I found a 3 minute clip of the cast reading ep...   12      9  2017
# 12  After much anxiety and about 3 tries, I finall...   13      9  2017
# 13  I had a massive breakdown at work yesterday an...   14      9  2017
# 14  If anyone wants to talk I'd really appreciate ...   15      9  2017
# 15  Last night I sent an email to the information ...   16      9  2017
# 16  I dont know if this is the right place to post...   17      9  2017
# 17  I just need to get it off my chest. I always f...   18      9  2017
# 18     Most of the people I know have given up on me.   19      9  2017
# 19  I've been depressed for basically my whole lif...   20      9  2017
# 20  I overeat when I'm depressed or anxious. For t...   21      9  2017
# 21  No common sense of humor, interests, values et...   22      9  2017
# 22  So I kinda want to die, but I'm not suicidal, ...   23      9  2017
# 23  My boyfriend and I are skipping Christmas this...   24      9  2017
# 24  I don't want anyone to be sad. I don't want an...   25      9  2017
# 25  Ever since I moved away for school, Ive been s...   26      9  2017
# 26  I dream about a crush I used to have (well, at...   27      9  2017
# 27  I'm exhausted. Physically and mentally. Depres...   28      9  2017
# 28  Does anyone else ever get wrapped up in existe...   29      9  2017
# 29  but I don't want to kill myself.I look around ...   30      9  2017
# 30  Really feeling out of it, like really dissocia...    1     10  2017
# 31  I'm 25, college grad, engineer, fiancee, 50k s...    2     10  2017
# 32  Did facebook's mobile app change it's layout a...    3     10  2017
# 33  Truly heartbreakingl. I'm sorry this has happe...    4     10  2017
# 34  When your squad has a scili room reserved but ...    5     10  2017
# 35  Gotta get my shyte together for a filled Frida...    6     10  2017
# 36  Marching season has ended and I go back to a p...    7     10  2017
# 37  Uni experience is the kitchen being dirty but ...    8     10  2017
# 38  If a massive corporate tax cut at the expense ...    9     10  2017
# 39  Had a visit from my nephew DJ and family stopp...   10     10  2017
# 40                   It's lit! 🎆🎇✨ #CornellHomecoming   11     10  2017
# 41  NCSSM sent me an email /basically/ telling me ...   12     10  2017
# 42       Physics has taken over my life. #FyxixIzPhun   13     10  2017
# 43  James of Royal Pirates has uploaded an origina...   14     10  2017
# 44  Spring Break has officially begun. Usually, I ...   15     10  2017
# 45  Faq it. Music is music, and it doesn't matter ...   16     10  2017
# 46  I am glad my painting skills were of use this ...   17     10  2017
# 47  This, my friends, is an OPPO phone. It's what ...   18     10  2017
# 48  Produce 101 Season 2 has officially ended. Con...   19     10  2017
# 49  Wtf. Bomb threats or not, "fans" shouldn't be ...   20     10  2017
# 50  Marching season has ended and I go back to a p...   21     10  2017
# 51  Just trying to live life by dabbing my way thr...   22     10  2017
#
#           date
# 0   01/09/2017
# 1   02/09/2017
# 2   03/09/2017
# 3   04/09/2017
# 4   05/09/2017
# 5   06/09/2017
# 6   07/09/2017
# 7   08/09/2017
# 8   09/09/2017
# 9   10/09/2017
# 10  11/09/2017
# 11  12/09/2017
# 12  13/09/2017
# 13  14/09/2017
# 14  15/09/2017
# 15  16/09/2017
# 16  17/09/2017
# 17  18/09/2017
# 18  19/09/2017
# 19  20/09/2017
# 20  21/09/2017
# 21  22/09/2017
# 22  23/09/2017
# 23  24/09/2017
# 24  25/09/2017
# 25  26/09/2017
# 26  27/09/2017
# 27  28/09/2017
# 28  29/09/2017
# 29  30/09/2017
# 30  01/10/2017
# 31  02/10/2017
# 32  03/10/2017
# 33  04/10/2017
# 34  05/10/2017
# 35  06/10/2017
# 36  07/10/2017
# 37  08/10/2017
# 38  09/10/2017
# 39  10/10/2017
# 40  11/10/2017
# 41  12/10/2017
# 42  13/10/2017
# 43  14/10/2017
# 44  15/10/2017
# 45  16/10/2017
# 46  17/10/2017
# 47  18/10/2017
# 48  19/10/2017
# 49  20/10/2017
# 50  21/10/2017
# 51  22/10/2017
